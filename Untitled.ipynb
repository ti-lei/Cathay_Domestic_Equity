# %%
import pandas as pd

# %%
pd.read_csv('Data.csv')
# Out:
#        Colors Country          Deliver       Product   Size   TimeStemp
# 0       White      Us         In Stock      IphoneXr   64GB  2019-08-02
# 1       White      Us         In Stock      IphoneXr  128GB  2019-08-02
# 2       White      Us         In Stock      IphoneXr  256GB  2019-08-02
# 3       Black      Us         In Stock      IphoneXr   64GB  2019-08-02
# 4       Black      Us         In Stock      IphoneXr  128GB  2019-08-02
# 5       Black      Us         In Stock      IphoneXr  256GB  2019-08-02
# 6        Blue      Us         In Stock      IphoneXr   64GB  2019-08-02
# 7        Blue      Us         In Stock      IphoneXr  128GB  2019-08-02
# 8        Blue      Us         In Stock      IphoneXr  256GB  2019-08-02
# 9      Yellow      Us         In Stock      IphoneXr   64GB  2019-08-02
# 10     Yellow      Us         In Stock      IphoneXr  128GB  2019-08-02
# 11     Yellow      Us         In Stock      IphoneXr  256GB  2019-08-02
# ...

# %%
a = pd.read_csv('Data.csv')

# %%
a = a.drop(a[(a['TimeStemp'] == '2019-08-02') &(a['Deliver'] == '火 2019/08/06')].index)

# %%
b = a

# %%
b.to_csv('Data.csv',index = False)
